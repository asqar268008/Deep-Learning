# %%
import torch 
import torch.nn as nn
import torch.optim as optim
torch.set_printoptions(linewidth=120)
import torch.nn.functional as F
import torchvision
from torch.utils.tensorboard import SummaryWriter
import torchvision.transforms as transforms
from itertools import product

# %%
def get_num_correct(preds, labels):
    return preds.argmax(dim=1).eq(labels).sum().item()

# %%
#CNN model
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=5)

        self.fc1 = nn.Linear(in_features=12 * 4 * 4, out_features=120)
        self.fc2 = nn.Linear(in_features=120, out_features=60)
        self.out = nn.Linear(in_features=60, out_features=10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, kernel_size=2, stride=2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, kernel_size=2, stride=2)
        x = torch.flatten(x, start_dim = 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

# %%
train_set = torchvision.datasets.FashionMNIST(
    root = './data/FashionMNIST',
    train = True,
    download = True,
    transform = transforms.ToTensor())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#Hyperparameters
paramerters = dict(
    lr = [0.01, 0.001],
    batch_size = [32, 64, 128],
    shuffle = [True, False]
)

param_values = [v for v in paramerters.values()]
# Out:
# 100%|██████████| 26.4M/26.4M [04:30<00:00, 97.7kB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 69.5kB/s]
# 100%|██████████| 4.42M/4.42M [00:23<00:00, 192kB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 8.77MB/s]

# %%
model_t = CNN()
for run_id, (lr, batch_size, shuffle) in enumerate(product(*param_values)):
    print('Run id:', run_id)
    train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=shuffle)
    model = CNN().to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    comment = f' batch_size = {batch_size} lr = {lr} shuffle_{shuffle}'
    tb = SummaryWriter(comment=comment)
    images, labels = next(iter(train_loader))
    grid = torchvision.utils.make_grid(images)
    tb.add_image('images', grid)
    tb.add_graph(model_t, images)

    for epoch in range(5):
        total_loss = 0
        total_correct = 0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            preds = model(images)

            loss = criterion(preds, labels)
            total_loss += loss.item()
            total_correct += get_num_correct(preds, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        tb.add_scalar('Loss', total_loss, epoch)
        tb.add_scalar('Correct', total_correct, epoch)
        tb.add_scalar('Accuracy', total_correct/len(train_set), epoch)

        print('batch_size', batch_size, 'lr', lr, 'shuffle', shuffle)
        print('epoch', epoch, 'total_correct:', total_correct, 'loss:', total_loss)
    print('-------------------------------------------------------------------')
    tb.add_hparams(
        {'lr': lr, 'batch_size': batch_size, 'shuffle': shuffle},
        {
            'accuracy': total_correct/len(train_set),
            'loss': total_loss,
        },
        )

tb.close()
# Out:
# Run id: 0
# batch_size 32 lr 0.01 shuffle True
# epoch 0 total_correct: 47471 loss: 1041.5790256336331
# batch_size 32 lr 0.01 shuffle True
# epoch 1 total_correct: 50565 loss: 804.1287724226713
# batch_size 32 lr 0.01 shuffle True
# epoch 2 total_correct: 51105 loss: 772.3443571180105
# batch_size 32 lr 0.01 shuffle True
# epoch 3 total_correct: 51225 loss: 755.1587502472103
# batch_size 32 lr 0.01 shuffle True
# epoch 4 total_correct: 51346 loss: 740.9222726151347
# -------------------------------------------------------------------
# Run id: 1
# batch_size 32 lr 0.01 shuffle False
# epoch 0 total_correct: 48407 loss: 978.7986023500562
# batch_size 32 lr 0.01 shuffle False
# epoch 1 total_correct: 50949 loss: 772.2412153184414
# batch_size 32 lr 0.01 shuffle False
# epoch 2 total_correct: 51296 loss: 743.3958904966712
# batch_size 32 lr 0.01 shuffle False
# epoch 3 total_correct: 51665 loss: 719.8462783880532
# batch_size 32 lr 0.01 shuffle False
# epoch 4 total_correct: 51624 loss: 723.77579459548
# -------------------------------------------------------------------
# Run id: 2
# batch_size 64 lr 0.01 shuffle True
# epoch 0 total_correct: 47283 loss: 524.0077617019415
# batch_size 64 lr 0.01 shuffle True
# epoch 1 total_correct: 51537 loss: 362.82492838054895
# batch_size 64 lr 0.01 shuffle True
# epoch 2 total_correct: 52154 loss: 332.3075243681669
# batch_size 64 lr 0.01 shuffle True
# epoch 3 total_correct: 52411 loss: 324.8651844114065
# batch_size 64 lr 0.01 shuffle True
# epoch 4 total_correct: 52589 loss: 315.53901679068804
# -------------------------------------------------------------------
# Run id: 3
# batch_size 64 lr 0.01 shuffle False
# epoch 0 total_correct: 47682 loss: 509.3606286942959
# batch_size 64 lr 0.01 shuffle False
# epoch 1 total_correct: 51317 loss: 371.78980569541454
# batch_size 64 lr 0.01 shuffle False
# epoch 2 total_correct: 51737 loss: 347.86280776560307
# batch_size 64 lr 0.01 shuffle False
# epoch 3 total_correct: 52010 loss: 338.31334598362446
# batch_size 64 lr 0.01 shuffle False
# epoch 4 total_correct: 52393 loss: 327.94895397126675
# -------------------------------------------------------------------
# Run id: 4
# batch_size 128 lr 0.01 shuffle True
# epoch 0 total_correct: 46058 loss: 283.9055875390768
# batch_size 128 lr 0.01 shuffle True
# epoch 1 total_correct: 51549 loss: 178.8270291686058
# batch_size 128 lr 0.01 shuffle True
# epoch 2 total_correct: 52253 loss: 161.844931229949
# batch_size 128 lr 0.01 shuffle True
# epoch 3 total_correct: 52801 loss: 151.61532594263554
# batch_size 128 lr 0.01 shuffle True
# epoch 4 total_correct: 52993 loss: 146.04229889810085
# -------------------------------------------------------------------
# Run id: 5
# batch_size 128 lr 0.01 shuffle False
# epoch 0 total_correct: 47216 loss: 263.8814819455147
# batch_size 128 lr 0.01 shuffle False
# epoch 1 total_correct: 51821 loss: 173.5435558706522
# batch_size 128 lr 0.01 shuffle False
# epoch 2 total_correct: 52459 loss: 158.44219788908958
# batch_size 128 lr 0.01 shuffle False
# epoch 3 total_correct: 52945 loss: 148.44627764821053
# batch_size 128 lr 0.01 shuffle False
# epoch 4 total_correct: 53033 loss: 146.15359485149384
# -------------------------------------------------------------------
# Run id: 6
# batch_size 32 lr 0.001 shuffle True
# epoch 0 total_correct: 45174 loss: 1233.5583953261375
# batch_size 32 lr 0.001 shuffle True
# epoch 1 total_correct: 50757 loss: 789.4419469535351
# batch_size 32 lr 0.001 shuffle True
# epoch 2 total_correct: 52071 loss: 674.0588586591184
# batch_size 32 lr 0.001 shuffle True
# epoch 3 total_correct: 52773 loss: 610.5281130671501
# batch_size 32 lr 0.001 shuffle True
# epoch 4 total_correct: 53273 loss: 565.4085451047868
# -------------------------------------------------------------------
# Run id: 7
# batch_size 32 lr 0.001 shuffle False
# epoch 0 total_correct: 44855 loss: 1235.9148470908403
# batch_size 32 lr 0.001 shuffle False
# epoch 1 total_correct: 50409 loss: 819.5189522877336
# batch_size 32 lr 0.001 shuffle False
# epoch 2 total_correct: 51826 loss: 696.8264503143728
# batch_size 32 lr 0.001 shuffle False
# epoch 3 total_correct: 52526 loss: 635.2047200202942
# batch_size 32 lr 0.001 shuffle False
# epoch 4 total_correct: 52995 loss: 593.3187836706638
# -------------------------------------------------------------------
# Run id: 8
# batch_size 64 lr 0.001 shuffle True
# epoch 0 total_correct: 43621 loss: 686.0362573266029
# batch_size 64 lr 0.001 shuffle True
# epoch 1 total_correct: 49494 loss: 446.16181153059006
# batch_size 64 lr 0.001 shuffle True
# epoch 2 total_correct: 51285 loss: 376.481385409832
# batch_size 64 lr 0.001 shuffle True
# epoch 3 total_correct: 52160 loss: 338.7232293188572
# batch_size 64 lr 0.001 shuffle True
# epoch 4 total_correct: 52701 loss: 313.0015588775277
# -------------------------------------------------------------------
# Run id: 9
# batch_size 64 lr 0.001 shuffle False
# epoch 0 total_correct: 43977 loss: 668.4845451712608
# batch_size 64 lr 0.001 shuffle False
# epoch 1 total_correct: 49638 loss: 442.24382588267326
# batch_size 64 lr 0.001 shuffle False
# epoch 2 total_correct: 51279 loss: 369.8756901919842
# batch_size 64 lr 0.001 shuffle False
# epoch 3 total_correct: 52124 loss: 332.5743884295225
# batch_size 64 lr 0.001 shuffle False
# epoch 4 total_correct: 52715 loss: 307.5060637444258
# -------------------------------------------------------------------
# Run id: 10
# batch_size 128 lr 0.001 shuffle True
# epoch 0 total_correct: 41244 loss: 387.37352964282036
# batch_size 128 lr 0.001 shuffle True
# epoch 1 total_correct: 47749 loss: 252.14605742692947
# batch_size 128 lr 0.001 shuffle True
# epoch 2 total_correct: 49713 loss: 218.92820544540882
# batch_size 128 lr 0.001 shuffle True
# epoch 3 total_correct: 50894 loss: 195.90723709762096
# batch_size 128 lr 0.001 shuffle True
# epoch 4 total_correct: 51505 loss: 181.93007822334766
# -------------------------------------------------------------------
# Run id: 11
# batch_size 128 lr 0.001 shuffle False
# epoch 0 total_correct: 41333 loss: 386.4407018125057
# batch_size 128 lr 0.001 shuffle False
# epoch 1 total_correct: 48461 loss: 240.53652846813202
# batch_size 128 lr 0.001 shuffle False
# epoch 2 total_correct: 50296 loss: 208.04374746978283
# batch_size 128 lr 0.001 shuffle False
# epoch 3 total_correct: 51222 loss: 188.33075815439224
# batch_size 128 lr 0.001 shuffle False
# epoch 4 total_correct: 51846 loss: 174.4560672044754
# -------------------------------------------------------------------

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 25932), started 0:02:47 ago. (Use '!kill 25932' to kill it.)
#       <iframe id="tensorboard-frame-7a5e3e8c1e341f6f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7a5e3e8c1e341f6f");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
